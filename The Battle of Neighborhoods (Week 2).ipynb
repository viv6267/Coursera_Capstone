# %% [markdown]
# # Week-2

# %% [markdown]
# # # Battle of the Neighborhoods
#
# # Indian Restaurants
#
# ___________________________________________________________________________________________
#
#
# # Introduction
#
# This final project explores the best locations for Indian restaurants throughout the city of New York. Food Business/Entrepreneur News stated that worldwide Indian Food sales were up for the second year in a row with the United Sates holding the largest market (Donley, 2018). New York is a major metropolitan area with more than 8.4 million (Quick Facts, 2018) people living within city limits. Most of the Indian immigration into the United States occurred during the late 19th and early 20th century with over two million immigrants between 1900 and 1910. With almost 600,000 Manhattan inhabitants reporting Indian ancestry, the need to find and enjoy Indian cuisine is on the rise. This report explores which neighborhoods and boroughs of New York City have the most as well as the best Indian restaurants. Additionally, I will attempt to answer the questions “Where should I open an Indian Restaurant?” and “Where should I stay If I want great Indian food?”
#
# --------------------------------------------------------------------------------------------------
#
# # Data
#
# In order to answer the above questions, data on New York City neighborhoods, boroughs to include boundaries, latitude, longitude, restaurants, and restaurant ratings and tips are required.
#
# New York City data containing the neighborhoods and boroughs, latitudes, and longitudes will be obtained from the data source: https://cocl.us/new_york_dataset
#
# New York City data containing neighborhood boundaries will be obtained from the data source: https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm
#
# All data related to locations and quality of Italian restaurants will be obtained via the FourSquare API utilized via the Request library in Python.
#
# ------------------------------------------------------------------------------------------------
#
# # Methodology
#
# • Data will be collected from https://cocl.us/new_york_dataset and cleaned and processed into a dataframe.
#
# • FourSquare be used to locate all venues and then filtered by Indian restaurants. Ratings, tips, and likes by users     will be counted and added to the dataframe.
#
# • Data will be sorted based on rankings
#
# • Finally, the data be will be visually assessed using graphing from various Python libraries.
#
# -----------------------------------------------------------------------------------------------
#
# # Problem Statement
# 1. What is / are the best location(s) for Indian cuisine in New York City?
# 2. In what Neighborhood and/or borough should I open an Indian restaurant to have the best chance of being successful?
# 3. Where would I go in New York City to have the best Indian food?
# -------------------------------------------------------------------------------------------------
#
# # Loaded Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '3EXERUJ1BU55HCBYYUMUNP25A1SFRIA250YTW04WQEUC1QI1' # your Foursquare ID
CLIENT_SECRET = 'ORBSD4OB55AJVIPFNPW43MF5SHIVQHVYJVR1XVSDY40ZNGU0' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3EXERUJ1BU55HCBYYUMUNP25A1SFRIA250YTW04WQEUC1QI1
# CLIENT_SECRET:ORBSD4OB55AJVIPFNPW43MF5SHIVQHVYJVR1XVSDY40ZNGU0

# %%
import json
#with open('C:\\Users\\vkuma140\\Music\\Interview point\\IBM VISUALIZATION\\Machine Learning\\ml_capstone\\newyork_data.json') as json_data:
    #newyork_data = json.load(json_data)

# %%
address = 'New York'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude,longitude)
# Out:
# 40.7127281 -74.0060152

# %%
search_query = 'Indian'
radius = 400
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %%
#url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format  CLIENT_ID, CLIENT_SECRET, 
           
#url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=3EXERUJ1BU55HCBYYUMUNP25A1SFRIA250YTW04WQEUC1QI1&client_secret=ORBSD4OB55AJVIPFNPW43MF5SHIVQHVYJVR1XVSDY40ZNGU0&v=20180604&ll=40.7127281,-74.0060152&radius=400&limit=100'

# %%
#@results = requests.get(url).json()
#results

# %%
#venue_data=results["response"]['groups'][0]['items']
#venue_data
#venue_details=[]
#for row in venue_data:
#    try:
#        venue_id=row['venue']['id']
#        venue_name=row['venue']['name']
#        venue_category=row['venue']['categories'][0]['name']
#        venue_details.append([venue_id,venue_name,venue_category])
#    except KeyError:
#        pass
#column_names=['ID','Name','Category']
#df1 = pd.DataFrame(venue_details,columns=column_names)
#df1.tail()
# Out:
#                           ID                              Name  \
# 95  58fd2804f79faa1c9cb04e81                   Vivi Bubble Tea
# 96  4c573237b7a31b8db0b54fda                St. Andrew's Plaza
# 97  3fd66200f964a520f4e41ee3                              Ecco
# 98  50b02338e4b047828b2277c1                           Benares
# 99  4ea89e6702d5b8174e85e65e  20 Thomas St. (The Flea Theater)
#
#               Category
# 95     Bubble Tea Shop
# 96               Plaza
# 97  Italian Restaurant
# 98   Indian Restaurant
# 99             Theater

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    return new_york_data

# %%
NY_data = get_new_york_data()
NY_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
import matplotlib.pyplot as plt

col = "green"
NY_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color=col)
plt.title('Neighborhoods per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. Neighborhoods',fontsize = 15)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name']
indian_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in NY_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(latitude,longitude)
    indian_resturants=venues[venues['Category']=='Indian Restaurant']   
    print('(',count,'/',len(NY_data),')','Indian Resturants in '+Neighborhood+', '+Borough+':'+str(len(indian_resturants)))
    print(row)
    for resturant_detail in indian_resturants.values.tolist():
        id, name , category=resturant_detail
        indian_rest_ny = indian_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Indian Resturants in Wakefield, Bronx:2
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 2 / 306 ) Indian Resturants in Co-op City, Bronx:2
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 3 / 306 ) Indian Resturants in Eastchester, Bronx:2
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 4 / 306 ) Indian Resturants in Fieldston, Bronx:2
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 5 / 306 ) Indian Resturants in Riverdale, Bronx:2
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 6 / 306 ) Indian Resturants in Kingsbridge, Bronx:2
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 7 / 306 ) Indian Resturants in Marble Hill, Manhattan:2
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 8 / 306 ) Indian Resturants in Woodlawn, Bronx:2
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 9 / 306 ) Indian Resturants in Norwood, Bronx:2
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 10 / 306 ) Indian Resturants in Williamsbridge, Bronx:2
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 11 / 306 ) Indian Resturants in Baychester, Bronx:2
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 12 / 306 ) Indian Resturants in Pelham Parkway, Bronx:2
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 13 / 306 ) Indian Resturants in City Island, Bronx:2
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 14 / 306 ) Indian Resturants in Bedford Park, Bronx:2
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 15 / 306 ) Indian Resturants in University Heights, Bronx:2
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 16 / 306 ) Indian Resturants in Morris Heights, Bronx:2
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 17 / 306 ) Indian Resturants in Fordham, Bronx:2
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 18 / 306 ) Indian Resturants in East Tremont, Bronx:2
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 19 / 306 ) Indian Resturants in West Farms, Bronx:2
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 20 / 306 ) Indian Resturants in High  Bridge, Bronx:2
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 21 / 306 ) Indian Resturants in Melrose, Bronx:2
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 22 / 306 ) Indian Resturants in Mott Haven, Bronx:2
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 23 / 306 ) Indian Resturants in Port Morris, Bronx:2
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 24 / 306 ) Indian Resturants in Longwood, Bronx:2
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 25 / 306 ) Indian Resturants in Hunts Point, Bronx:2
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 26 / 306 ) Indian Resturants in Morrisania, Bronx:2
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 27 / 306 ) Indian Resturants in Soundview, Bronx:2
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 28 / 306 ) Indian Resturants in Clason Point, Bronx:2
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 29 / 306 ) Indian Resturants in Throgs Neck, Bronx:2
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 30 / 306 ) Indian Resturants in Country Club, Bronx:2
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 31 / 306 ) Indian Resturants in Parkchester, Bronx:2
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 32 / 306 ) Indian Resturants in Westchester Square, Bronx:2
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 33 / 306 ) Indian Resturants in Van Nest, Bronx:2
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 34 / 306 ) Indian Resturants in Morris Park, Bronx:2
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 35 / 306 ) Indian Resturants in Belmont, Bronx:2
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 36 / 306 ) Indian Resturants in Spuyten Duyvil, Bronx:2
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 37 / 306 ) Indian Resturants in North Riverdale, Bronx:2
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 38 / 306 ) Indian Resturants in Pelham Bay, Bronx:2
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 39 / 306 ) Indian Resturants in Schuylerville, Bronx:2
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 40 / 306 ) Indian Resturants in Edgewater Park, Bronx:2
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 41 / 306 ) Indian Resturants in Castle Hill, Bronx:2
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 42 / 306 ) Indian Resturants in Olinville, Bronx:2
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 43 / 306 ) Indian Resturants in Pelham Gardens, Bronx:2
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 44 / 306 ) Indian Resturants in Concourse, Bronx:2
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 45 / 306 ) Indian Resturants in Unionport, Bronx:2
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 46 / 306 ) Indian Resturants in Edenwald, Bronx:2
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 47 / 306 ) Indian Resturants in Bay Ridge, Brooklyn:2
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 48 / 306 ) Indian Resturants in Bensonhurst, Brooklyn:2
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 49 / 306 ) Indian Resturants in Sunset Park, Brooklyn:2
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 50 / 306 ) Indian Resturants in Greenpoint, Brooklyn:2
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 51 / 306 ) Indian Resturants in Gravesend, Brooklyn:2
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 52 / 306 ) Indian Resturants in Brighton Beach, Brooklyn:2
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 53 / 306 ) Indian Resturants in Sheepshead Bay, Brooklyn:2
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 54 / 306 ) Indian Resturants in Manhattan Terrace, Brooklyn:2
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 55 / 306 ) Indian Resturants in Flatbush, Brooklyn:2
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 56 / 306 ) Indian Resturants in Crown Heights, Brooklyn:2
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 57 / 306 ) Indian Resturants in East Flatbush, Brooklyn:2
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 58 / 306 ) Indian Resturants in Kensington, Brooklyn:2
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 59 / 306 ) Indian Resturants in Windsor Terrace, Brooklyn:2
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 60 / 306 ) Indian Resturants in Prospect Heights, Brooklyn:2
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 61 / 306 ) Indian Resturants in Brownsville, Brooklyn:2
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 62 / 306 ) Indian Resturants in Williamsburg, Brooklyn:2
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 63 / 306 ) Indian Resturants in Bushwick, Brooklyn:2
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 64 / 306 ) Indian Resturants in Bedford Stuyvesant, Brooklyn:2
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 65 / 306 ) Indian Resturants in Brooklyn Heights, Brooklyn:2
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 66 / 306 ) Indian Resturants in Cobble Hill, Brooklyn:2
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 67 / 306 ) Indian Resturants in Carroll Gardens, Brooklyn:2
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 68 / 306 ) Indian Resturants in Red Hook, Brooklyn:2
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 69 / 306 ) Indian Resturants in Gowanus, Brooklyn:2
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 70 / 306 ) Indian Resturants in Fort Greene, Brooklyn:2
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 71 / 306 ) Indian Resturants in Park Slope, Brooklyn:2
# ['Brooklyn', 'Park Slope', 40.67232052268197, -73.97705030183924]
# ( 72 / 306 ) Indian Resturants in Cypress Hills, Brooklyn:2
# ['Brooklyn', 'Cypress Hills', 40.68239101144211, -73.87661596457296]
# ( 73 / 306 ) Indian Resturants in East New York, Brooklyn:2
# ['Brooklyn', 'East New York', 40.669925700847045, -73.88069863917366]
# ( 74 / 306 ) Indian Resturants in Starrett City, Brooklyn:2
# ['Brooklyn', 'Starrett City', 40.64758905230874, -73.87936970045875]
# ( 75 / 306 ) Indian Resturants in Canarsie, Brooklyn:2
# ['Brooklyn', 'Canarsie', 40.63556432797428, -73.90209269778966]
# ( 76 / 306 ) Indian Resturants in Flatlands, Brooklyn:2
# ['Brooklyn', 'Flatlands', 40.630446043757466, -73.92911302644674]
# ( 77 / 306 ) Indian Resturants in Mill Island, Brooklyn:2
# ['Brooklyn', 'Mill Island', 40.606336421685626, -73.90818571777423]
# ( 78 / 306 ) Indian Resturants in Manhattan Beach, Brooklyn:2
# ['Brooklyn', 'Manhattan Beach', 40.57791350308657, -73.94353722891886]
# ( 79 / 306 ) Indian Resturants in Coney Island, Brooklyn:2
# ['Brooklyn', 'Coney Island', 40.57429256471601, -73.98868295821637]
# ( 80 / 306 ) Indian Resturants in Bath Beach, Brooklyn:2
# ['Brooklyn', 'Bath Beach', 40.59951870282238, -73.99875221443519]
# ( 81 / 306 ) Indian Resturants in Borough Park, Brooklyn:2
# ['Brooklyn', 'Borough Park', 40.633130512758015, -73.99049823044811]
# ( 82 / 306 ) Indian Resturants in Dyker Heights, Brooklyn:2
# ['Brooklyn', 'Dyker Heights', 40.619219457722636, -74.01931375636022]
# ( 83 / 306 ) Indian Resturants in Gerritsen Beach, Brooklyn:2
# ['Brooklyn', 'Gerritsen Beach', 40.590848433902046, -73.93010170691196]
# ( 84 / 306 ) Indian Resturants in Marine Park, Brooklyn:2
# ['Brooklyn', 'Marine Park', 40.609747779894604, -73.93134404108497]
# ( 85 / 306 ) Indian Resturants in Clinton Hill, Brooklyn:2
# ['Brooklyn', 'Clinton Hill', 40.693229421881504, -73.96784306216367]
# ( 86 / 306 ) Indian Resturants in Sea Gate, Brooklyn:2
# ['Brooklyn', 'Sea Gate', 40.57637537890224, -74.0078731120024]
# ( 87 / 306 ) Indian Resturants in Downtown, Brooklyn:2
# ['Brooklyn', 'Downtown', 40.69084402109802, -73.98346337431099]
# ( 88 / 306 ) Indian Resturants in Boerum Hill, Brooklyn:2
# ['Brooklyn', 'Boerum Hill', 40.685682912091444, -73.98374824115798]
# ( 89 / 306 ) Indian Resturants in Prospect Lefferts Gardens, Brooklyn:2
# ['Brooklyn', 'Prospect Lefferts Gardens', 40.658420017469815, -73.95489867077713]
# ( 90 / 306 ) Indian Resturants in Ocean Hill, Brooklyn:2
# ['Brooklyn', 'Ocean Hill', 40.678402554795355, -73.91306831787395]
# ( 91 / 306 ) Indian Resturants in City Line, Brooklyn:2
# ['Brooklyn', 'City Line', 40.67856995727479, -73.86797598081334]
# ( 92 / 306 ) Indian Resturants in Bergen Beach, Brooklyn:2
# ['Brooklyn', 'Bergen Beach', 40.61514955045308, -73.89855633630317]
# ( 93 / 306 ) Indian Resturants in Midwood, Brooklyn:2
# ['Brooklyn', 'Midwood', 40.62559589869843, -73.95759523489838]
# ( 94 / 306 ) Indian Resturants in Prospect Park South, Brooklyn:2
# ['Brooklyn', 'Prospect Park South', 40.647008603185185, -73.96261316716048]
# ( 95 / 306 ) Indian Resturants in Georgetown, Brooklyn:2
# ['Brooklyn', 'Georgetown', 40.62384524478419, -73.91607483951324]
# ( 96 / 306 ) Indian Resturants in East Williamsburg, Brooklyn:2
# ['Brooklyn', 'East Williamsburg', 40.70849241041548, -73.93885815269195]
# ( 97 / 306 ) Indian Resturants in North Side, Brooklyn:2
# ['Brooklyn', 'North Side', 40.714822906532014, -73.95880857587582]
# ( 98 / 306 ) Indian Resturants in South Side, Brooklyn:2
# ['Brooklyn', 'South Side', 40.71086147265064, -73.95800095153331]
# ( 99 / 306 ) Indian Resturants in Ocean Parkway, Brooklyn:2
# ['Brooklyn', 'Ocean Parkway', 40.61305976667942, -73.96836678035541]
# ( 100 / 306 ) Indian Resturants in Fort Hamilton, Brooklyn:2
# ['Brooklyn', 'Fort Hamilton', 40.61476812694226, -74.03197914537984]
# ( 101 / 306 ) Indian Resturants in Chinatown, Manhattan:2
# ['Manhattan', 'Chinatown', 40.71561842231432, -73.99427936255978]
# ( 102 / 306 ) Indian Resturants in Washington Heights, Manhattan:2
# ['Manhattan', 'Washington Heights', 40.85190252555305, -73.93690027985234]
# ( 103 / 306 ) Indian Resturants in Inwood, Manhattan:2
# ['Manhattan', 'Inwood', 40.86768396449915, -73.92121042203897]
# ( 104 / 306 ) Indian Resturants in Hamilton Heights, Manhattan:2
# ['Manhattan', 'Hamilton Heights', 40.823604284811935, -73.94968791883366]
# ( 105 / 306 ) Indian Resturants in Manhattanville, Manhattan:2
# ['Manhattan', 'Manhattanville', 40.8169344294978, -73.9573853935188]
# ( 106 / 306 ) Indian Resturants in Central Harlem, Manhattan:2
# ['Manhattan', 'Central Harlem', 40.81597606742414, -73.94321112603905]
# ( 107 / 306 ) Indian Resturants in East Harlem, Manhattan:2
# ['Manhattan', 'East Harlem', 40.79224946663033, -73.94418223148524]
# ( 108 / 306 ) Indian Resturants in Upper East Side, Manhattan:2
# ['Manhattan', 'Upper East Side', 40.775638573301805, -73.96050763135]
# ( 109 / 306 ) Indian Resturants in Yorkville, Manhattan:2
# ['Manhattan', 'Yorkville', 40.775929849884875, -73.94711784471826]
# ( 110 / 306 ) Indian Resturants in Lenox Hill, Manhattan:2
# ['Manhattan', 'Lenox Hill', 40.76811265828733, -73.9588596881376]
# ( 111 / 306 ) Indian Resturants in Roosevelt Island, Manhattan:2
# ['Manhattan', 'Roosevelt Island', 40.76215960576283, -73.94916769227953]
# ( 112 / 306 ) Indian Resturants in Upper West Side, Manhattan:2
# ['Manhattan', 'Upper West Side', 40.787657998534854, -73.97705923630603]
# ( 113 / 306 ) Indian Resturants in Lincoln Square, Manhattan:2
# ['Manhattan', 'Lincoln Square', 40.77352888942166, -73.98533777001262]
# ( 114 / 306 ) Indian Resturants in Clinton, Manhattan:2
# ['Manhattan', 'Clinton', 40.75910089146212, -73.99611936309479]
# ( 115 / 306 ) Indian Resturants in Midtown, Manhattan:2
# ['Manhattan', 'Midtown', 40.75469110270623, -73.98166882730304]
# ( 116 / 306 ) Indian Resturants in Murray Hill, Manhattan:2
# ['Manhattan', 'Murray Hill', 40.748303077252174, -73.97833207924127]
# ( 117 / 306 ) Indian Resturants in Chelsea, Manhattan:2
# ['Manhattan', 'Chelsea', 40.744034706747975, -74.00311633472813]
# ( 118 / 306 ) Indian Resturants in Greenwich Village, Manhattan:2
# ['Manhattan', 'Greenwich Village', 40.72693288536128, -73.99991402945902]
# ( 119 / 306 ) Indian Resturants in East Village, Manhattan:2
# ['Manhattan', 'East Village', 40.727846777270244, -73.98222616506416]
# ( 120 / 306 ) Indian Resturants in Lower East Side, Manhattan:2
# ['Manhattan', 'Lower East Side', 40.71780674892765, -73.98089031999291]
# ( 121 / 306 ) Indian Resturants in Tribeca, Manhattan:2
# ['Manhattan', 'Tribeca', 40.721521967443216, -74.01068328559087]
# ( 122 / 306 ) Indian Resturants in Little Italy, Manhattan:2
# ['Manhattan', 'Little Italy', 40.71932379395907, -73.99730467208073]
# ( 123 / 306 ) Indian Resturants in Soho, Manhattan:2
# ['Manhattan', 'Soho', 40.72218384131794, -74.00065666959759]
# ( 124 / 306 ) Indian Resturants in West Village, Manhattan:2
# ['Manhattan', 'West Village', 40.73443393572434, -74.00617998126812]
# ( 125 / 306 ) Indian Resturants in Manhattan Valley, Manhattan:2
# ['Manhattan', 'Manhattan Valley', 40.797307041702865, -73.96428617740655]
# ( 126 / 306 ) Indian Resturants in Morningside Heights, Manhattan:2
# ['Manhattan', 'Morningside Heights', 40.807999738165826, -73.96389627905332]
# ( 127 / 306 ) Indian Resturants in Gramercy, Manhattan:2
# ['Manhattan', 'Gramercy', 40.737209832715, -73.98137594833541]
# ( 128 / 306 ) Indian Resturants in Battery Park City, Manhattan:2
# ['Manhattan', 'Battery Park City', 40.71193198394565, -74.01686930508617]
# ( 129 / 306 ) Indian Resturants in Financial District, Manhattan:2
# ['Manhattan', 'Financial District', 40.70710710727048, -74.0106654452127]
# ( 130 / 306 ) Indian Resturants in Astoria, Queens:2
# ['Queens', 'Astoria', 40.76850859335492, -73.91565374304234]
# ( 131 / 306 ) Indian Resturants in Woodside, Queens:2
# ['Queens', 'Woodside', 40.74634908860222, -73.90184166838284]
# ( 132 / 306 ) Indian Resturants in Jackson Heights, Queens:2
# ['Queens', 'Jackson Heights', 40.75198138007367, -73.88282109164365]
# ( 133 / 306 ) Indian Resturants in Elmhurst, Queens:2
# ['Queens', 'Elmhurst', 40.744048505122024, -73.88165622288388]
# ( 134 / 306 ) Indian Resturants in Howard Beach, Queens:2
# ['Queens', 'Howard Beach', 40.65422527738487, -73.8381376460028]
# ( 135 / 306 ) Indian Resturants in Corona, Queens:2
# ['Queens', 'Corona', 40.74238175015667, -73.85682497345258]
# ( 136 / 306 ) Indian Resturants in Forest Hills, Queens:2
# ['Queens', 'Forest Hills', 40.72526378216503, -73.84447500788983]
# ( 137 / 306 ) Indian Resturants in Kew Gardens, Queens:2
# ['Queens', 'Kew Gardens', 40.7051790354148, -73.82981905825703]
# ( 138 / 306 ) Indian Resturants in Richmond Hill, Queens:2
# ['Queens', 'Richmond Hill', 40.69794731471763, -73.83183321446887]
# ( 139 / 306 ) Indian Resturants in Flushing, Queens:2
# ['Queens', 'Flushing', 40.76445419697846, -73.83177300329582]
# ( 140 / 306 ) Indian Resturants in Long Island City, Queens:2
# ['Queens', 'Long Island City', 40.75021734610528, -73.93920223915505]
# ( 141 / 306 ) Indian Resturants in Sunnyside, Queens:2
# ['Queens', 'Sunnyside', 40.74017628351924, -73.92691617561577]
# ( 142 / 306 ) Indian Resturants in East Elmhurst, Queens:2
# ['Queens', 'East Elmhurst', 40.76407323883091, -73.86704147658772]
# ( 143 / 306 ) Indian Resturants in Maspeth, Queens:2
# ['Queens', 'Maspeth', 40.725427374093606, -73.89621713626859]
# ( 144 / 306 ) Indian Resturants in Ridgewood, Queens:2
# ['Queens', 'Ridgewood', 40.70832315613858, -73.90143517559589]
# ( 145 / 306 ) Indian Resturants in Glendale, Queens:2
# ['Queens', 'Glendale', 40.70276242967838, -73.87074167435605]
# ( 146 / 306 ) Indian Resturants in Rego Park, Queens:2
# ['Queens', 'Rego Park', 40.72897409480735, -73.8578268690537]
# ( 147 / 306 ) Indian Resturants in Woodhaven, Queens:2
# ['Queens', 'Woodhaven', 40.68988687915789, -73.8581104655432]
# ( 148 / 306 ) Indian Resturants in Ozone Park, Queens:2
# ['Queens', 'Ozone Park', 40.680708468265415, -73.84320266173447]
# ( 149 / 306 ) Indian Resturants in South Ozone Park, Queens:2
# ['Queens', 'South Ozone Park', 40.66854957767195, -73.80986478649041]
# ( 150 / 306 ) Indian Resturants in College Point, Queens:2
# ['Queens', 'College Point', 40.784902749260205, -73.84304528896125]
# ( 151 / 306 ) Indian Resturants in Whitestone, Queens:2
# ['Queens', 'Whitestone', 40.78129076602694, -73.81420216610863]
# ( 152 / 306 ) Indian Resturants in Bayside, Queens:2
# ['Queens', 'Bayside', 40.76604063281064, -73.7742736306867]
# ( 153 / 306 ) Indian Resturants in Auburndale, Queens:2
# ['Queens', 'Auburndale', 40.76172954903262, -73.79176243728061]
# ( 154 / 306 ) Indian Resturants in Little Neck, Queens:2
# ['Queens', 'Little Neck', 40.7708261928267, -73.7388977558074]
# ( 155 / 306 ) Indian Resturants in Douglaston, Queens:2
# ['Queens', 'Douglaston', 40.76684609790763, -73.7424982072733]
# ( 156 / 306 ) Indian Resturants in Glen Oaks, Queens:2
# ['Queens', 'Glen Oaks', 40.74944079974332, -73.71548118999145]
# ( 157 / 306 ) Indian Resturants in Bellerose, Queens:2
# ['Queens', 'Bellerose', 40.72857318176675, -73.72012814826903]
# ( 158 / 306 ) Indian Resturants in Kew Gardens Hills, Queens:2
# ['Queens', 'Kew Gardens Hills', 40.722578244228046, -73.82087764933566]
# ( 159 / 306 ) Indian Resturants in Fresh Meadows, Queens:2
# ['Queens', 'Fresh Meadows', 40.7343944653313, -73.78271337003264]
# ( 160 / 306 ) Indian Resturants in Briarwood, Queens:2
# ['Queens', 'Briarwood', 40.71093547252271, -73.81174822458634]
# ( 161 / 306 ) Indian Resturants in Jamaica Center, Queens:2
# ['Queens', 'Jamaica Center', 40.70465736068717, -73.79690165888289]
# ( 162 / 306 ) Indian Resturants in Oakland Gardens, Queens:2
# ['Queens', 'Oakland Gardens', 40.74561857141855, -73.75494976234332]
# ( 163 / 306 ) Indian Resturants in Queens Village, Queens:2
# ['Queens', 'Queens Village', 40.718893092167356, -73.73871484578424]
# ( 164 / 306 ) Indian Resturants in Hollis, Queens:2
# ['Queens', 'Hollis', 40.71124344191904, -73.75925009335594]
# ( 165 / 306 ) Indian Resturants in South Jamaica, Queens:2
# ['Queens', 'South Jamaica', 40.696911253789885, -73.7904261313554]
# ( 166 / 306 ) Indian Resturants in St. Albans, Queens:2
# ['Queens', 'St. Albans', 40.69444538522359, -73.75867603727717]
# ( 167 / 306 ) Indian Resturants in Rochdale, Queens:2
# ['Queens', 'Rochdale', 40.67521139591733, -73.77258787620906]
# ( 168 / 306 ) Indian Resturants in Springfield Gardens, Queens:2
# ['Queens', 'Springfield Gardens', 40.666230490368584, -73.76042092682287]
# ( 169 / 306 ) Indian Resturants in Cambria Heights, Queens:2
# ['Queens', 'Cambria Heights', 40.692774639160845, -73.73526873708026]
# ( 170 / 306 ) Indian Resturants in Rosedale, Queens:2
# ['Queens', 'Rosedale', 40.659816433428084, -73.73526079428278]
# ( 171 / 306 ) Indian Resturants in Far Rockaway, Queens:2
# ['Queens', 'Far Rockaway', 40.603134432500894, -73.75497968043872]
# ( 172 / 306 ) Indian Resturants in Broad Channel, Queens:2
# ['Queens', 'Broad Channel', 40.60302658351238, -73.8200548911032]
# ( 173 / 306 ) Indian Resturants in Breezy Point, Queens:2
# ['Queens', 'Breezy Point', 40.55740128845452, -73.92551196994168]
# ( 174 / 306 ) Indian Resturants in Steinway, Queens:2
# ['Queens', 'Steinway', 40.775923015642896, -73.90228960391673]
# ( 175 / 306 ) Indian Resturants in Beechhurst, Queens:2
# ['Queens', 'Beechhurst', 40.79278140360048, -73.80436451720988]
# ( 176 / 306 ) Indian Resturants in Bay Terrace, Queens:2
# ['Queens', 'Bay Terrace', 40.782842806245554, -73.7768022262158]
# ( 177 / 306 ) Indian Resturants in Edgemere, Queens:2
# ['Queens', 'Edgemere', 40.595641807368494, -73.77613282391705]
# ( 178 / 306 ) Indian Resturants in Arverne, Queens:2
# ['Queens', 'Arverne', 40.58914394372971, -73.79199233136943]
# ( 179 / 306 ) Indian Resturants in Rockaway Beach, Queens:2
# ['Queens', 'Rockaway Beach', 40.582801696845586, -73.82236121088751]
# ( 180 / 306 ) Indian Resturants in Neponsit, Queens:2
# ['Queens', 'Neponsit', 40.572036730217015, -73.85754672410827]
# ( 181 / 306 ) Indian Resturants in Murray Hill, Queens:2
# ['Queens', 'Murray Hill', 40.764126122614066, -73.81276269135866]
# ( 182 / 306 ) Indian Resturants in Floral Park, Queens:2
# ['Queens', 'Floral Park', 40.741378421945434, -73.70884705889246]
# ( 183 / 306 ) Indian Resturants in Holliswood, Queens:2
# ['Queens', 'Holliswood', 40.7209572076444, -73.76714166714729]
# ( 184 / 306 ) Indian Resturants in Jamaica Estates, Queens:2
# ['Queens', 'Jamaica Estates', 40.71680483014613, -73.7872269693666]
# ( 185 / 306 ) Indian Resturants in Queensboro Hill, Queens:2
# ['Queens', 'Queensboro Hill', 40.7445723092867, -73.82580915110559]
# ( 186 / 306 ) Indian Resturants in Hillcrest, Queens:2
# ['Queens', 'Hillcrest', 40.723824901829204, -73.79760300912672]
# ( 187 / 306 ) Indian Resturants in Ravenswood, Queens:2
# ['Queens', 'Ravenswood', 40.761704526054146, -73.93157506072878]
# ( 188 / 306 ) Indian Resturants in Lindenwood, Queens:2
# ['Queens', 'Lindenwood', 40.66391841925139, -73.84963782402441]
# ( 189 / 306 ) Indian Resturants in Laurelton, Queens:2
# ['Queens', 'Laurelton', 40.66788389660247, -73.74025607989822]
# ( 190 / 306 ) Indian Resturants in Lefrak City, Queens:2
# ['Queens', 'Lefrak City', 40.736074570830795, -73.8625247141374]
# ( 191 / 306 ) Indian Resturants in Belle Harbor, Queens:2
# ['Queens', 'Belle Harbor', 40.57615556543109, -73.8540175039252]
# ( 192 / 306 ) Indian Resturants in Rockaway Park, Queens:2
# ['Queens', 'Rockaway Park', 40.58034295646131, -73.84153370226186]
# ( 193 / 306 ) Indian Resturants in Somerville, Queens:2
# ['Queens', 'Somerville', 40.59771061565768, -73.79664750844047]
# ( 194 / 306 ) Indian Resturants in Brookville, Queens:2
# ['Queens', 'Brookville', 40.66000322733613, -73.75175310731153]
# ( 195 / 306 ) Indian Resturants in Bellaire, Queens:2
# ['Queens', 'Bellaire', 40.73301404027834, -73.73889198912481]
# ( 196 / 306 ) Indian Resturants in North Corona, Queens:2
# ['Queens', 'North Corona', 40.7540709990489, -73.85751790676447]
# ( 197 / 306 ) Indian Resturants in Forest Hills Gardens, Queens:2
# ['Queens', 'Forest Hills Gardens', 40.7146110815117, -73.8410221123401]
# ( 198 / 306 ) Indian Resturants in St. George, Staten Island:2
# ['Staten Island', 'St. George', 40.6449815710044, -74.07935312512797]
# ( 199 / 306 ) Indian Resturants in New Brighton, Staten Island:2
# ['Staten Island', 'New Brighton', 40.64061455913511, -74.08701650516625]
# ( 200 / 306 ) Indian Resturants in Stapleton, Staten Island:2
# ['Staten Island', 'Stapleton', 40.62692762538176, -74.07790192660066]
# ( 201 / 306 ) Indian Resturants in Rosebank, Staten Island:2
# ['Staten Island', 'Rosebank', 40.61530494652761, -74.06980526716141]
# ( 202 / 306 ) Indian Resturants in West Brighton, Staten Island:2
# ['Staten Island', 'West Brighton', 40.63187892654607, -74.1071817826561]
# ( 203 / 306 ) Indian Resturants in Grymes Hill, Staten Island:2
# ['Staten Island', 'Grymes Hill', 40.624184791313006, -74.08724819983729]
# ( 204 / 306 ) Indian Resturants in Todt Hill, Staten Island:2
# ['Staten Island', 'Todt Hill', 40.59706851814673, -74.1113288180088]
# ( 205 / 306 ) Indian Resturants in South Beach, Staten Island:2
# ['Staten Island', 'South Beach', 40.58024741350956, -74.0795529253982]
# ( 206 / 306 ) Indian Resturants in Port Richmond, Staten Island:2
# ['Staten Island', 'Port Richmond', 40.63366930554365, -74.12943426797008]
# ( 207 / 306 ) Indian Resturants in Mariner's Harbor, Staten Island:2
# ['Staten Island', "Mariner's Harbor", 40.632546390481124, -74.15008537046981]
# ( 208 / 306 ) Indian Resturants in Port Ivory, Staten Island:2
# ['Staten Island', 'Port Ivory', 40.63968297845542, -74.17464532993542]
# ( 209 / 306 ) Indian Resturants in Castleton Corners, Staten Island:2
# ['Staten Island', 'Castleton Corners', 40.61333593766742, -74.11918058534842]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-7c1ef3b9e6f4> in <module>
#       5 for row in NY_data.values.tolist():
#       6     Borough, Neighborhood, Latitude, Longitude=row
# ----> 7     venues = get_venues(latitude,longitude)
#       8     indian_resturants=venues[venues['Category']=='Indian Restaurant']
#       9     print('(',count,'/',len(NY_data),')','Indian Resturants in '+Neighborhood+', '+Borough+':'+str(len(indian_resturants)))
#
# <ipython-input-115-6c03cb9e7143> in get_venues(lat, lng)
#      14     # get all the data
#      15     results = requests.get(url).json()
# ---> 16     venue_data=results["response"]['groups'][0]['items']
#      17     venue_details=[]
#      18     for row in venue_data:
#
# KeyError: 'groups'

# %%
indian_rest_ny.to_csv('indian_rest_ny_tocsv1.csv')

# %%
indian_rest_ny=pd.read_csv('indian_rest_ny_tocsv1.csv')

print('shape is:-',indian_rest_ny.shape)
indian_rest_ny.head()
# Out:
# shape is:- (26, 5)
#    Unnamed: 0 Borough Neighborhood                        ID  \
# 0           0   Bronx    Wakefield  575dea4c498e2739e43a27e2
# 1           1   Bronx    Wakefield  50b02338e4b047828b2277c1
# 2           2   Bronx   Co-op City  575dea4c498e2739e43a27e2
# 3           3   Bronx   Co-op City  50b02338e4b047828b2277c1
# 4           4   Bronx  Eastchester  575dea4c498e2739e43a27e2
#
#                    Name
# 0  Aahar Indian Cuisine
# 1               Benares
# 2  Aahar Indian Cuisine
# 3               Benares
# 4  Aahar Indian Cuisine

# %%
NOofNeigh = 6 # top number for graphing all the same past 6
colo='pink'
indian_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(NOofNeigh).plot.bar(figsize=(10,5), color=colo)
plt.title('Indian Resturants per Neighborhood: NYC', fontsize = 20)
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('Indian Resturants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
col1='brown'
indian_rest_ny.groupby('Borough')['ID'].count().plot.bar(figsize=(10,5), color = col1)
plt.title('Indian Resturants per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of Indian Resturants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
indian_rest_ny[indian_rest_ny['Neighborhood']=='Baychester']
# Out:
#     Unnamed: 0 Borough Neighborhood                        ID  \
# 20          20   Bronx   Baychester  575dea4c498e2739e43a27e2
# 21          21   Bronx   Baychester  50b02338e4b047828b2277c1
#
#                     Name
# 20  Aahar Indian Cuisine
# 21               Benares

# %%
indian_rest_ny[indian_rest_ny['Neighborhood']=='City Island']
# Out:
#     Unnamed: 0 Borough Neighborhood                        ID  \
# 24          24   Bronx  City Island  575dea4c498e2739e43a27e2
# 25          25   Bronx  City Island  50b02338e4b047828b2277c1
#
#                     Name
# 24  Aahar Indian Cuisine
# 25               Benares

# %%
def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response'][0]['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df2 = pd.DataFrame(venue_details,columns=column_names)
    return df2

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
indian_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1
for row in indian_rest_ny.values.tolist():
    Borough=row
    Neighborhood=row
    ID=row
    Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(indian_rest_ny),')','processed')
    indian_rest_stats_ny = indian_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
indian_rest_stats_ny.tail()
# Out:
# {'meta': {'code': 400, 'errorType': 'param_error', 'errorDetail': "Value [0,%20'Bronx',%20'Wakefield',%20'575dea4c498e2739e43a27e2',%20'Aahar%20Indian%20Cuisine'] is invalid for venue id", 'requestId': '5dbc8724bbed210038be9b3a'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-7419b0470ef1> in <module>
#       8     Name=row
#       9     try:
# ---> 10         venue_details=get_venue_details(ID)
#      11         print(venue_details)
#      12         id,name,likes,rating,tips=venue_details.values.tolist()[0]
#
# <ipython-input-155-f8375dc26031> in get_venue_details(venue_id)
#       9     results = requests.get(url).json()
#      10     print(results)
# ---> 11     venue_data=results['response'][1]['venue']
#      12     venue_details=[]
#      13     try:
#
# KeyError: 1

# %% [markdown]
# #  # After fetching all the data, I could see there is no response for Indian Restaurants(See above). Hence I'm not able to find the rating of each Indian Restaurant. But I have done rest of the part that will help us to get out the best Indian Restaurant in different location.

# %%
indian_rest_stats_ny.tail()
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, ID, Name, Likes, Rating, Tips]
# Index: []

# %%
indian_rest_stats_ny['Likes']=indian_rest_stats_ny['Likes'].astype('float64')
indian_rest_stats_ny['Tips']=indian_rest_stats_ny['Tips'].astype('float64')
indian_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 7 columns):
# Borough         0 non-null object
# Neighborhood    0 non-null object
# ID              0 non-null object
# Name            0 non-null object
# Likes           0 non-null float64
# Rating          0 non-null object
# Tips            0 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 0.0+ bytes

# %%
#indian_rest_stats_ny.describes()

# %%
indian_rest_stats_ny[indian_rest_stats_ny['Likes'].idmax()]

# %%
indian_rest_stats_ny[indian_rest_stats_ny['Rating'].idmax()]

# %%
#indian_rest_stats_ny[indian_rest_stats_ny['Tips'].idmax()]

# %%
ny_neighborhood_stats=indian_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)

# %%
ny_borough_stats=indian_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=8.0]
ny_neighborhood_stats

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,NY_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
ny_neighborhood_stats

# %%
 create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=14)
 instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()
 loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'
 add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
    add incidents to map
ny_map.add_child(incidents)

# %% [markdown]
# # ----------------------------------------------------------------------------------------------
#
# #  Results / Conclusion
#
# Bronx and Manhattan have the best rated Indian restaurants on average. The Bronx has the higest number of Indian restaurants per borough. However, of note, Baychester, City Island, and co-op city etc has  the neighborhood in all of NYC with the same Indian Restaurants. Despite Manhattan having the least number of neighborhoods as comparison to Bronx but, it has the most Indian restaurants. Based on this information, I would state that Manhattan and Bronx are the best locations for Indian cuisine in NYC. To have the best shot of success, I would open an Indian restaurants in Bronx. Bronx has multiple neighborhoods with average ratings exceeding 8.0 of a scale of 1.0 to 10.0 and has the least number of Indian restaurants making competition easier than in other boroughs. . As a final note, all of the above analysis is depended on the adequacy and accuracy of Four Square data. A more comprehensive analysis and future work would need to incorporate data from other external databases.
